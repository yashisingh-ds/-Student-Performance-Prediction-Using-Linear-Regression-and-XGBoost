# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_mat=pd.read_csv("/content/student-mat.csv",sep=';')
df_por=pd.read_csv("/content/student-por.csv",sep=';')

# %%
df_mat.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df_por.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
print(x_train.dtypes)
# Out:
# G1           int64
# health       int64
# absences     int64
# G2           int64
# freetime     int64
# goout        int64
# Dalc         int64
# famrel       int64
# Medu         int64
# Fedu         int64
# age          int64
# Walc         int64
# school      object
# sex         object
# address     object
# famsize     object
# Mjob        object
# Fjob        object
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error ,r2_score

# %%
categorical_cols = ['school', 'sex', 'address', 'famsize', 'Mjob', 'Fjob']

# %%
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), categorical_cols)], remainder='passthrough')

# %%
x_train = ct.fit_transform(x_train)
x_test = ct.transform(x_test)

# %%
features=['G1','health','absences','G2','freetime','goout','Dalc','famrel','Medu','Fedu','age', 'Walc','school', 'sex', 'address','famsize','Mjob','Fjob']
target='G3'

# %%
x_train =df_mat[features]
x_test=df_mat[features]
y_train=df_mat[target]
y_test=df_mat[target]

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse=mean_squared_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

print("Mean Squared Error :" , mse)
print("R-Squared :", r2)
# Out:
# Mean Squared Error : 3.3627275881892946
# R-Squared : 0.8393842762116263

# %%
r2 =r2_score(y_test,y_pred)
accuarcy =r2*100
print("Accuarcy :", accuarcy)
# Out:
# Accuarcy : 83.93842762116263

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()
xgb.fit(x_train, y_train)

accuracy = xgb.score(x_test, y_test)
print("XGBoost Accuracy:", accuracy)
# Out:
# XGBoost Accuracy: 0.9999980926513672

# %% [markdown]
# # New Section
